# %% [markdown]
# ## Facial keypoints detection
#
# In this task you will create facial keypoint detector based on CNN regressor.
#
#
# ![title](example.png)

# %% [markdown]
# ### Load and preprocess data

# %% [markdown]
# Script `get_data.py` unpacks data — images and labelled points. 6000 images are located in `images` folder and keypoint coordinates are in `gt.csv` file. Run the cell below to unpack data.

# %%
from get_data import unpack
unpack('facial-keypoints-data.zip')

# %% [markdown]
# Now you have to read `gt.csv` file and images from `images` dir. File `gt.csv` contains header and ground truth points for every image in `images` folder. It has 29 columns. First column is a filename and next 28 columns are `x` and `y` coordinates for 14 facepoints. We will make following preprocessing:
# 1. Scale all images to resolution $100 \times 100$ pixels.
# 2. Scale all coordinates to range $[-0.5; 0.5]$. To obtain that, divide all x's by width (or number of columns) of image, and divide all y's by height (or number of rows) of image and subtract 0.5 from all values.
#
# Function `load_imgs_and_keypoint` should return a tuple of two numpy arrays: `imgs` of shape `(N, 100, 100, 3)`, where `N` is the number of images and `points` of shape `(N, 28)`.

# %%
### Useful routines for preparing data
import numpy as np
from os.path import join
from skimage.color import gray2rgb
from skimage.io import imread
from skimage.transform import resize
import glob

def load_imgs_and_keypoints(dirname='./'):
    # Write your code for loading images and points here
    points = np.genfromtxt(dirname + 'data/gt.csv', delimiter=',')[:,1:][1:]
    print(points.shape)
    
    odd = [i for i in range (0,28,2)]
    even = [i for i in range(1,28,2)]
    
    images = []
    for i, file in enumerate(glob.glob(dirname + 'data/images/*')):
        if i % 1000 == 0:
            print ("[*] Image", i)
        img = gray2rgb(imread(file))
        
        height, width, _ = img.shape
        
        points[i, odd] /= width
        points[i, odd] -= 0.5
        points[i, even] /= height - 0.5
        points[i, even] -= 0.5
        
        
        img = resize(img, [100,100,3])
    
        images.append(img)
         
    imgs = np.array(images)
    print(imgs.shape)

    
    return imgs, points

imgs, points = load_imgs_and_keypoints()
# Out:
# (6000, 28)
# [*] Image 0
# C:\Users\damyg\AppData\Local\conda\conda\envs\tf36\lib\site-packages\skimage\transform\_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\damyg\AppData\Local\conda\conda\envs\tf36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# [*] Image 1000
# [*] Image 2000
# [*] Image 3000
# [*] Image 4000
# [*] Image 5000
# (6000, 100, 100, 3)

# %%
# Example of output
# %matplotlib inline
from skimage.io import imshow
imshow(imgs[0])
points[0]
# Out:
# array([-0.30534351, -0.30497132, -0.01526718, -0.27055449,  0.14503817,
#        -0.25143403,  0.27480916, -0.30114723, -0.24045802, -0.20554493,
#        -0.17557252, -0.21319312, -0.08015267, -0.18642447,  0.11068702,
#        -0.16730402,  0.15267176, -0.19789675,  0.23664122, -0.17877629,
#         0.09541985,  0.05066922, -0.14885496,  0.16539197,  0.03435115,
#         0.18833652,  0.14122137,  0.18451243])

# %% [markdown]
# ### Visualize data

# %% [markdown]
# Let's prepare a function to visualize points on image. Such function obtains two arguments: an image and a vector of points' coordinates and draws points on image (just like first image in this notebook).

# %%
import matplotlib.pyplot as plt
# Circle may be useful for drawing points on face
# See matplotlib documentation for more info
from matplotlib.patches import Circle

def visualize_points(img, points):
    # Write here function which obtains image and normalized
    # coordinates and visualizes points on image
    fig, ax = plt.subplots(1)
    ax.set_aspect('equal')
    ax.imshow(img)
    
    for i in range(0,28,2):
        c = Circle(((points[i]+0.5)*100, (points[i+1]+0.5)*100), 2)
        ax.add_patch(c)
    plt.show()
    
    
visualize_points(imgs[1], points[1])

# %% [markdown]
# ### Train/val split

# %% [markdown]
# Run the following code to obtain train/validation split for training neural network.

# %%
from sklearn.model_selection import train_test_split
imgs_train, imgs_val, points_train, points_val = train_test_split(imgs, points, test_size=0.1)

# %% [markdown]
# ### Simple data augmentation

# %% [markdown]
# For better training we will use simple data augmentation — flipping an image and points. Implement function flip_img which flips an image and its' points. Make sure that points are flipped correctly! For instance, points on right eye now should be points on left eye (i.e. you have to mirror coordinates and swap corresponding points on the left and right sides of the face). VIsualize an example of original and flipped image.

# %%
def flip_img(img, points):
    # Write your code for flipping here
    img = img[:, ::-1]
    odd = [i for i in range(0,28,2)]
    even = [i for i in range(1,28,2)]

    f_points = np.zeros(points.shape)
    
    f_points[even] = points[even]
    f_points[odd] = - points[odd] 
    
    return img, f_points

visualize_points(imgs[1], points[1])

f_img, f_points = flip_img(imgs[1], points[1])
visualize_points(f_img, f_points)

# %% [markdown]
# Time to augment our training sample. Apply flip to every image in training sample. As a result you should obtain two arrays: `aug_imgs_train` and `aug_points_train` which contain original images and points along with flipped ones.

# %%
aug_imgs_train = np.zeros(imgs_train.shape)
aug_points_train = np.zeros(points_train.shape)

for i, (img, points) in enumerate(zip(imgs_train, points_train)):
    aug_imgs_train[i], aug_points_train[i] = flip_img(img, points)
    
aug_imgs_train = np.concatenate((aug_imgs_train, imgs_train), axis=0)
aug_points_train = np.concatenate((aug_points_train, points_train), axis=0)
aug_imgs_train.shape
# Out:
# (10800, 100, 100, 3)

# %%
visualize_points(aug_imgs_train[2], aug_points_train[2])

# %%
visualize_points(aug_imgs_train[3], aug_points_train[3])

# %% [markdown]
# ### Network architecture and training
#
# Now let's define neural network regressor. It will have 28 outputs, 2 numbers per point. The precise architecture is up to you. We recommend to add 2-3 (`Conv2D` + `MaxPooling2D`) pairs, then `Flatten` and 2-3 `Dense` layers. Don't forget about ReLU activations. We also recommend to add `Dropout` to every `Dense` layer (with p from 0.2 to 0.5) to prevent overfitting.

# %%
from keras.models import Sequential
from keras.layers import (
    Conv2D, MaxPooling2D, Flatten,
    Dense, Dropout, BatchNormalization
)

model = Sequential()
model.add(BatchNormalization())
model.add(Conv2D(24, (5,5), activation="relu"))
model.add(Dropout(0.2))
model.add(MaxPooling2D())
model.add(Conv2D(36, (5,5), activation="relu"))
model.add(Dropout(0.2))
model.add(MaxPooling2D())
model.add(Conv2D(48, (5,5), activation="relu"))
model.add(Dropout(0.2))
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3), activation="relu"))
model.add(Dropout(0.2))
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3), activation="relu"))

model.add(Flatten())

model.add(Dense(500, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(90, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(28))

# %% [markdown]
# Time to train! Since we are training a regressor, make sure that you use mean squared error (mse) as loss. Feel free to experiment with optimization method (SGD, Adam, etc.) and its' parameters.

# %%
# ModelCheckpoint can be used for saving model during training.
# Saved models are useful for finetuning your model 
# See keras documentation for more info
from keras.callbacks import ModelCheckpoint
from keras.optimizers import SGD, Adam

mc = ModelCheckpoint("best_model", verbose=1, save_best_only=True)

# Choose optimizer, compile model and run training
opt = Adam()

model.compile(opt, loss='mse')

model.fit(x=aug_imgs_train, 
          y=aug_points_train, 
          batch_size=64, 
          epochs=100, 
          callbacks=[mc], 
          validation_data=[imgs_val, points_val])
# Out:
# Train on 10800 samples, validate on 600 samples
# Epoch 1/100
# 10800/10800 [==============================] - 11s 1ms/step - loss: 0.0122 - val_loss: 0.0175
#
# Epoch 00001: val_loss improved from inf to 0.01752, saving model to best_model
# Epoch 2/100
# 10800/10800 [==============================] - 8s 719us/step - loss: 0.0117 - val_loss: 0.0153
#
# Epoch 00002: val_loss improved from 0.01752 to 0.01530, saving model to best_model
# Epoch 3/100
# 10800/10800 [==============================] - 8s 710us/step - loss: 0.0117 - val_loss: 0.0141
#
# Epoch 00003: val_loss improved from 0.01530 to 0.01414, saving model to best_model
# Epoch 4/100
# 10800/10800 [==============================] - 8s 712us/step - loss: 0.0114 - val_loss: 0.0185
#
# Epoch 00004: val_loss did not improve from 0.01414
# Epoch 5/100
# 10800/10800 [==============================] - 8s 713us/step - loss: 0.0113 - val_loss: 0.0170
#
# Epoch 00005: val_loss did not improve from 0.01414
# Epoch 6/100
# 10800/10800 [==============================] - 8s 719us/step - loss: 0.0112 - val_loss: 0.0181
#
# Epoch 00006: val_loss did not improve from 0.01414
# Epoch 7/100
# 10800/10800 [==============================] - 8s 710us/step - loss: 0.0109 - val_loss: 0.0154
#
# Epoch 00007: val_loss did not improve from 0.01414
# Epoch 8/100
# 10800/10800 [==============================] - 8s 714us/step - loss: 0.0108 - val_loss: 0.0162
#
# Epoch 00008: val_loss did not improve from 0.01414
# Epoch 9/100
# 10800/10800 [==============================] - 8s 717us/step - loss: 0.0108 - val_loss: 0.0155
#
# Epoch 00009: val_loss did not improve from 0.01414
# Epoch 10/100
# 10800/10800 [==============================] - 8s 712us/step - loss: 0.0104 - val_loss: 0.0149
#
# Epoch 00010: val_loss did not improve from 0.01414
# Epoch 11/100
# 10800/10800 [==============================] - 8s 706us/step - loss: 0.0104 - val_loss: 0.0172
#
# Epoch 00011: val_loss did not improve from 0.01414
# Epoch 12/100
# 10800/10800 [==============================] - 8s 707us/step - loss: 0.0104 - val_loss: 0.0167
#
# Epoch 00012: val_loss did not improve from 0.01414
# Epoch 13/100
# 10800/10800 [==============================] - 8s 718us/step - loss: 0.0102 - val_loss: 0.0167
#
# Epoch 00013: val_loss did not improve from 0.01414
# Epoch 14/100
# 10800/10800 [==============================] - 8s 716us/step - loss: 0.0099 - val_loss: 0.0205
#
# Epoch 00014: val_loss did not improve from 0.01414
# Epoch 15/100
# 10800/10800 [==============================] - 8s 708us/step - loss: 0.0100 - val_loss: 0.0181
#
# Epoch 00015: val_loss did not improve from 0.01414
# Epoch 16/100
# 10800/10800 [==============================] - 8s 710us/step - loss: 0.0099 - val_loss: 0.0172
#
# Epoch 00016: val_loss did not improve from 0.01414
# Epoch 17/100
# 10800/10800 [==============================] - 8s 717us/step - loss: 0.0094 - val_loss: 0.0211
#
# Epoch 00017: val_loss did not improve from 0.01414
# Epoch 18/100
# 10800/10800 [==============================] - 8s 722us/step - loss: 0.0095 - val_loss: 0.0189
#
# Epoch 00018: val_loss did not improve from 0.01414
# Epoch 19/100
# 10800/10800 [==============================] - 8s 710us/step - loss: 0.0094 - val_loss: 0.0147
#
# Epoch 00019: val_loss did not improve from 0.01414
# Epoch 20/100
# 10800/10800 [==============================] - 8s 710us/step - loss: 0.0093 - val_loss: 0.0157
#
# Epoch 00020: val_loss did not improve from 0.01414
# Epoch 21/100
# 10800/10800 [==============================] - 8s 713us/step - loss: 0.0093 - val_loss: 0.0189
#
# Epoch 00021: val_loss did not improve from 0.01414
# Epoch 22/100
# 10800/10800 [==============================] - 8s 710us/step - loss: 0.0089 - val_loss: 0.0222
#
# Epoch 00022: val_loss did not improve from 0.01414
# Epoch 23/100
# 10800/10800 [==============================] - 8s 708us/step - loss: 0.0091 - val_loss: 0.0207
#
# Epoch 00023: val_loss did not improve from 0.01414
# Epoch 24/100
# 10800/10800 [==============================] - 8s 707us/step - loss: 0.0089 - val_loss: 0.0206
#
# Epoch 00024: val_loss did not improve from 0.01414
# Epoch 25/100
# 10800/10800 [==============================] - 8s 718us/step - loss: 0.0088 - val_loss: 0.0174
#
# Epoch 00025: val_loss did not improve from 0.01414
# Epoch 26/100
# 10800/10800 [==============================] - 8s 716us/step - loss: 0.0086 - val_loss: 0.0194
#
# Epoch 00026: val_loss did not improve from 0.01414
# Epoch 27/100
# 10800/10800 [==============================] - 8s 708us/step - loss: 0.0086 - val_loss: 0.0185
#
# Epoch 00027: val_loss did not improve from 0.01414
# Epoch 28/100
# 10800/10800 [==============================] - 8s 709us/step - loss: 0.0085 - val_loss: 0.0192
#
# Epoch 00028: val_loss did not improve from 0.01414
# Epoch 29/100
# 10800/10800 [==============================] - 8s 716us/step - loss: 0.0083 - val_loss: 0.0190
#
# Epoch 00029: val_loss did not improve from 0.01414
# Epoch 30/100
# 10800/10800 [==============================] - 8s 722us/step - loss: 0.0084 - val_loss: 0.0177
#
# Epoch 00030: val_loss did not improve from 0.01414
# Epoch 31/100
# 10800/10800 [==============================] - 8s 713us/step - loss: 0.0082 - val_loss: 0.0196
#
# Epoch 00031: val_loss did not improve from 0.01414
# Epoch 32/100
# 10800/10800 [==============================] - 8s 711us/step - loss: 0.0083 - val_loss: 0.0171
#
# Epoch 00032: val_loss did not improve from 0.01414
# Epoch 33/100
# 10800/10800 [==============================] - 8s 717us/step - loss: 0.0082 - val_loss: 0.0197
#
# Epoch 00033: val_loss did not improve from 0.01414
# Epoch 34/100
# 10800/10800 [==============================] - 8s 715us/step - loss: 0.0080 - val_loss: 0.0188
#
# Epoch 00034: val_loss did not improve from 0.01414
# Epoch 35/100
# 10800/10800 [==============================] - 8s 721us/step - loss: 0.0077 - val_loss: 0.0177
#
# Epoch 00035: val_loss did not improve from 0.01414
# Epoch 36/100
# 10800/10800 [==============================] - 8s 716us/step - loss: 0.0076 - val_loss: 0.0192
#
# Epoch 00036: val_loss did not improve from 0.01414
# Epoch 37/100
# 10800/10800 [==============================] - 8s 721us/step - loss: 0.0078 - val_loss: 0.0169
#
# Epoch 00037: val_loss did not improve from 0.01414
# Epoch 38/100
# 10800/10800 [==============================] - 8s 712us/step - loss: 0.0076 - val_loss: 0.0171
#
# Epoch 00038: val_loss did not improve from 0.01414
# Epoch 39/100
# 10800/10800 [==============================] - 8s 709us/step - loss: 0.0075 - val_loss: 0.0167
#
# Epoch 00039: val_loss did not improve from 0.01414
# Epoch 40/100
# 10800/10800 [==============================] - 8s 712us/step - loss: 0.0074 - val_loss: 0.0175
#
# Epoch 00040: val_loss did not improve from 0.01414
# Epoch 41/100
# 10800/10800 [==============================] - 8s 715us/step - loss: 0.0076 - val_loss: 0.0198
#
# Epoch 00041: val_loss did not improve from 0.01414
# Epoch 42/100
# 10800/10800 [==============================] - 8s 715us/step - loss: 0.0075 - val_loss: 0.0209
#
# Epoch 00042: val_loss did not improve from 0.01414
# Epoch 43/100
# 10800/10800 [==============================] - 8s 711us/step - loss: 0.0072 - val_loss: 0.0189
#
# Epoch 00043: val_loss did not improve from 0.01414
# Epoch 44/100
# 10800/10800 [==============================] - 8s 716us/step - loss: 0.0072 - val_loss: 0.0233
#
# Epoch 00044: val_loss did not improve from 0.01414
# Epoch 45/100
# 10800/10800 [==============================] - 8s 712us/step - loss: 0.0073 - val_loss: 0.0189
#
# Epoch 00045: val_loss did not improve from 0.01414
# Epoch 46/100
# 10800/10800 [==============================] - 8s 709us/step - loss: 0.0071 - val_loss: 0.0205
#
# Epoch 00046: val_loss did not improve from 0.01414
# Epoch 47/100
# 10800/10800 [==============================] - 8s 707us/step - loss: 0.0072 - val_loss: 0.0216
#
# Epoch 00047: val_loss did not improve from 0.01414
# Epoch 48/100
# 10800/10800 [==============================] - 8s 711us/step - loss: 0.0071 - val_loss: 0.0160
#
# Epoch 00048: val_loss did not improve from 0.01414
# Epoch 49/100
# 10800/10800 [==============================] - 8s 722us/step - loss: 0.0072 - val_loss: 0.0184
#
# Epoch 00049: val_loss did not improve from 0.01414
# Epoch 50/100
# 10800/10800 [==============================] - 8s 709us/step - loss: 0.0070 - val_loss: 0.0191
#
# Epoch 00050: val_loss did not improve from 0.01414
# Epoch 51/100
# 10800/10800 [==============================] - 8s 709us/step - loss: 0.0069 - val_loss: 0.0212
#
# Epoch 00051: val_loss did not improve from 0.01414
# Epoch 52/100
# 10800/10800 [==============================] - 8s 710us/step - loss: 0.0070 - val_loss: 0.0202
#
# Epoch 00052: val_loss did not improve from 0.01414
# Epoch 53/100
# 10800/10800 [==============================] - 8s 721us/step - loss: 0.0066 - val_loss: 0.0161
#
# Epoch 00053: val_loss did not improve from 0.01414
# Epoch 54/100
# 10800/10800 [==============================] - 8s 711us/step - loss: 0.0067 - val_loss: 0.0203
#
# Epoch 00054: val_loss did not improve from 0.01414
# Epoch 55/100
# 10800/10800 [==============================] - 8s 714us/step - loss: 0.0067 - val_loss: 0.0194
#
# Epoch 00055: val_loss did not improve from 0.01414
# Epoch 56/100
# 10800/10800 [==============================] - 8s 711us/step - loss: 0.0066 - val_loss: 0.0198
#
# Epoch 00056: val_loss did not improve from 0.01414
# Epoch 57/100
# 10800/10800 [==============================] - 8s 723us/step - loss: 0.0068 - val_loss: 0.0175
#
# Epoch 00057: val_loss did not improve from 0.01414
# Epoch 58/100
# 10800/10800 [==============================] - 8s 716us/step - loss: 0.0066 - val_loss: 0.0188
#
# Epoch 00058: val_loss did not improve from 0.01414
# Epoch 59/100
# 10800/10800 [==============================] - 8s 714us/step - loss: 0.0065 - val_loss: 0.0180
#
# Epoch 00059: val_loss did not improve from 0.01414
# Epoch 60/100
# 10800/10800 [==============================] - 8s 703us/step - loss: 0.0063 - val_loss: 0.0195
#
# Epoch 00060: val_loss did not improve from 0.01414
# Epoch 61/100
# 10800/10800 [==============================] - 8s 718us/step - loss: 0.0064 - val_loss: 0.0190
#
# Epoch 00061: val_loss did not improve from 0.01414
# Epoch 62/100
# 10800/10800 [==============================] - 8s 711us/step - loss: 0.0062 - val_loss: 0.0216
#
# Epoch 00062: val_loss did not improve from 0.01414
# Epoch 63/100
# 10800/10800 [==============================] - 8s 714us/step - loss: 0.0063 - val_loss: 0.0217
#
# Epoch 00063: val_loss did not improve from 0.01414
# Epoch 64/100
# 10800/10800 [==============================] - 8s 706us/step - loss: 0.0063 - val_loss: 0.0224
#
# Epoch 00064: val_loss did not improve from 0.01414
# Epoch 65/100
# 10800/10800 [==============================] - 8s 716us/step - loss: 0.0063 - val_loss: 0.0183
#
# Epoch 00065: val_loss did not improve from 0.01414
# Epoch 66/100
# 10800/10800 [==============================] - 8s 714us/step - loss: 0.0061 - val_loss: 0.0229
#
# Epoch 00066: val_loss did not improve from 0.01414
# Epoch 67/100
# 10800/10800 [==============================] - 8s 707us/step - loss: 0.0062 - val_loss: 0.0204
#
# Epoch 00067: val_loss did not improve from 0.01414
# Epoch 68/100
# 10800/10800 [==============================] - 8s 705us/step - loss: 0.0061 - val_loss: 0.0202
#
# Epoch 00068: val_loss did not improve from 0.01414
# Epoch 69/100
# 10800/10800 [==============================] - 8s 716us/step - loss: 0.0061 - val_loss: 0.0198
#
# Epoch 00069: val_loss did not improve from 0.01414
# Epoch 70/100
# 10800/10800 [==============================] - 8s 719us/step - loss: 0.0060 - val_loss: 0.0228
#
# Epoch 00070: val_loss did not improve from 0.01414
# Epoch 71/100
# 10800/10800 [==============================] - 8s 734us/step - loss: 0.0059 - val_loss: 0.0170
#
# Epoch 00071: val_loss did not improve from 0.01414
# Epoch 72/100
# 10800/10800 [==============================] - 8s 724us/step - loss: 0.0060 - val_loss: 0.0193
#
# Epoch 00072: val_loss did not improve from 0.01414
# Epoch 73/100
# 10800/10800 [==============================] - 8s 732us/step - loss: 0.0058 - val_loss: 0.0218
#
# Epoch 00073: val_loss did not improve from 0.01414
# Epoch 74/100
# 10800/10800 [==============================] - 8s 734us/step - loss: 0.0058 - val_loss: 0.0238
#
# Epoch 00074: val_loss did not improve from 0.01414
# Epoch 75/100
# 10800/10800 [==============================] - 8s 716us/step - loss: 0.0059 - val_loss: 0.0231
#
# Epoch 00075: val_loss did not improve from 0.01414
# Epoch 76/100
# 10800/10800 [==============================] - 8s 730us/step - loss: 0.0060 - val_loss: 0.0201
#
# Epoch 00076: val_loss did not improve from 0.01414
# Epoch 77/100
# 10800/10800 [==============================] - 8s 721us/step - loss: 0.0061 - val_loss: 0.0231
#
# Epoch 00077: val_loss did not improve from 0.01414
# Epoch 78/100
# 10800/10800 [==============================] - 8s 723us/step - loss: 0.0059 - val_loss: 0.0192
#
# Epoch 00078: val_loss did not improve from 0.01414
# Epoch 79/100
# 10800/10800 [==============================] - 8s 709us/step - loss: 0.0055 - val_loss: 0.0216
#
# Epoch 00079: val_loss did not improve from 0.01414
# Epoch 80/100
# 10800/10800 [==============================] - 8s 714us/step - loss: 0.0058 - val_loss: 0.0167
#
# Epoch 00080: val_loss did not improve from 0.01414
# Epoch 81/100
# 10800/10800 [==============================] - 8s 708us/step - loss: 0.0057 - val_loss: 0.0215
#
# Epoch 00081: val_loss did not improve from 0.01414
# Epoch 82/100
# 10800/10800 [==============================] - 8s 719us/step - loss: 0.0054 - val_loss: 0.0230
#
# Epoch 00082: val_loss did not improve from 0.01414
# Epoch 83/100
# 10800/10800 [==============================] - 8s 715us/step - loss: 0.0058 - val_loss: 0.0193
#
# Epoch 00083: val_loss did not improve from 0.01414
# Epoch 84/100
# 10800/10800 [==============================] - 8s 711us/step - loss: 0.0055 - val_loss: 0.0229
#
# Epoch 00084: val_loss did not improve from 0.01414
# Epoch 85/100
# 10800/10800 [==============================] - 8s 722us/step - loss: 0.0055 - val_loss: 0.0205
#
# Epoch 00085: val_loss did not improve from 0.01414
# Epoch 86/100
# 10800/10800 [==============================] - 8s 719us/step - loss: 0.0055 - val_loss: 0.0180
#
# Epoch 00086: val_loss did not improve from 0.01414
# Epoch 87/100
# 10800/10800 [==============================] - 8s 718us/step - loss: 0.0056 - val_loss: 0.0199
#
# Epoch 00087: val_loss did not improve from 0.01414
# Epoch 88/100
# 10800/10800 [==============================] - 8s 715us/step - loss: 0.0055 - val_loss: 0.0227
#
# Epoch 00088: val_loss did not improve from 0.01414
# Epoch 89/100
# 10800/10800 [==============================] - 8s 714us/step - loss: 0.0054 - val_loss: 0.0201
#
# Epoch 00089: val_loss did not improve from 0.01414
# Epoch 90/100
# 10800/10800 [==============================] - 8s 714us/step - loss: 0.0055 - val_loss: 0.0210
#
# Epoch 00090: val_loss did not improve from 0.01414
# Epoch 91/100
# 10800/10800 [==============================] - 8s 729us/step - loss: 0.0055 - val_loss: 0.0191
#
# Epoch 00091: val_loss did not improve from 0.01414
# Epoch 92/100
# 10800/10800 [==============================] - 8s 718us/step - loss: 0.0054 - val_loss: 0.0194
#
# Epoch 00092: val_loss did not improve from 0.01414
# Epoch 93/100
# 10800/10800 [==============================] - 8s 720us/step - loss: 0.0052 - val_loss: 0.0187
#
# Epoch 00093: val_loss did not improve from 0.01414
# Epoch 94/100
# 10800/10800 [==============================] - 8s 715us/step - loss: 0.0053 - val_loss: 0.0188
#
# Epoch 00094: val_loss did not improve from 0.01414
# Epoch 95/100
# 10800/10800 [==============================] - 8s 702us/step - loss: 0.0054 - val_loss: 0.0216
#
# Epoch 00095: val_loss did not improve from 0.01414
# Epoch 96/100
# 10800/10800 [==============================] - 8s 707us/step - loss: 0.0051 - val_loss: 0.0192
#
# Epoch 00096: val_loss did not improve from 0.01414
# Epoch 97/100
# 10800/10800 [==============================] - 8s 735us/step - loss: 0.0051 - val_loss: 0.0205
#
# Epoch 00097: val_loss did not improve from 0.01414
# Epoch 98/100
# 10800/10800 [==============================] - 8s 729us/step - loss: 0.0053 - val_loss: 0.0243
#
# Epoch 00098: val_loss did not improve from 0.01414
# Epoch 99/100
# 10800/10800 [==============================] - 8s 721us/step - loss: 0.0054 - val_loss: 0.0199
#
# Epoch 00099: val_loss did not improve from 0.01414
# Epoch 100/100
# 10800/10800 [==============================] - 8s 724us/step - loss: 0.0052 - val_loss: 0.0198
#
# Epoch 00100: val_loss did not improve from 0.01414

# %% [markdown]
# ### Visualize results

# %% [markdown]
# Now visualize neural network results on several images from validation sample. Make sure that your network outputs different points for images (i.e. it doesn't output some constant).

# %%
predictions = model.predict(imgs_val[500:505])
for points, img in zip(predictions, imgs_val[500:505]):
    visualize_points(img, points)
